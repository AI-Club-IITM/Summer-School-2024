# %% [markdown]
# #INTRO TO PYTHON

# %% [markdown]
# Python is a programming language created by Guido Van Rossum
#
# ADVANTAGES::
#
# *   Simple Syntax : Easy to code, read and understand
#
# *   Has a lot of libraries and modules created by third parties , extending its functionality for various tasks
# * Dynamically typed - no need to declare data types explictly, making it flexible
# * Object Oriented and Procedural Programming Language

# %% [markdown]
# BUT WHY USE IT FOR ML?

# %% [markdown]
# Python has libraries like NumPy (for numerical calculations) and Pandas (for analyzing data)

# %% [markdown]
# #Basic:

# %% [markdown]
# Variables: storage containers for values

# %%
Name = "Anupama"
Math_Mark = 93.5
age = 17

# %%
print("Details are :", Name, age, Math_Mark)
# Out:
# Details are : Anupama 17 93.5

# %%
class = "12"    # Raises an error
# Out:
#   File "<ipython-input-6-8b945fceb5b3>", line 1
#     class = "12"    # Raises an error
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# This error occurs because class is a keyword - reserved words (that have a specific meaning),

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Print statement: Used to display a specified message on the screen

# %%
print(f"My name is {Name}")  #Another way to print an output
# Out:
# My name is Anupama

# %%
#Lines of code that are green(followed by #) are ignored by the interpreter.
#These are called comments and they are used to add information next to the code

# %% [markdown]
# ##Data Types:

# %%
x = 10  #int
y = 34
decimal = 1.23 #float
z = y < x
Name = "Preethana"     # When assigning variables to strings, the string should be in double quotations

# how to see what these variables store
print(x, y, Name, z )
# Out:
# 10 34 Preethana False

# %%
#how to see the data type these variables store
print( "we see data type using type() fucntion")
print(type(x))
print(type(y))
print(type(decimal))
print(type(Name))

# python automatically detects the data type of the variable
# Out:
# we see data type using type() fucntion
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Type casting : converting data from one type to another

# %%
a = float(1)        # a will be 1.0
b = str(5.6)      # note use str not string
c = int(5.6)      # c will be 5          NOTE: The number is NOT rounded off but the decimal part is stripped away

print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# 1.0 <class 'float'>
# 5.6 <class 'str'>
# 5 <class 'int'>

# %% [markdown]
# ##Input Statement:

# %% [markdown]
# Suppose we want to input the class name from the user

# %% [markdown]
# Syntax : input( " Enter message to be displayed")

# %%
class_name = input("enter the class")
print("You are in class", class_name)

type(class_name)
# Out:
# enter the class12
# You are in class 12
# str

# %% [markdown]
# Input is taken in as string by default

# %%
## Supoose we only want to input an integer, then we type cast as int
class_name = int(input("enter the class"))
print("You are in class", class_name)
type(class_name)
# Out:
# enter the class12
# You are in class 12
# int

# %% [markdown]
# ## Operators : Perform different processes on variables and constant

# %% [markdown]
# Arithmetic Operators:
#
# 1. Addition (+)
# 2. Subtaction (-)
# 3. Multiplication(*)
# 4. Division (/)
# 5. Modulus or remainder (%)
# 6. Exponent (**)

# %%
a = 5
b = 6

# operations in order

print('a + b = ', a + b)
print('b - 2 = ', b - 2)
print('a*4 =', a * 4)
print('b/3 = ', b/3)
print('a % b = ', a%b) # 5/6 q=0 rem=5
print('a^2 = ', a**2 )    # Don't forget: exponent is not ^, it is **
# Out:
# a + b =  11
# b - 2 =  4
# a*4 = 20
# b/3 =  2.0
# a % b =  5
# a^2 =  25

# %% [markdown]
# ###Comparison Operators
#
#
# 1.    Check equality (== )
# 2.    Check inequality(!= or <>)
# 3.    Greater than (>)
# 4.    Less than(<)
# 5.    Greater than or equal to (>=)
# 6.    Less than or equal to (<=)
#
# When used in expressions,  the truth value of the expression returned.

# %%
a = 5
b = 6

#operations in order

print(a==b)
print(b!=2)
print(a>4)
print(b<3)
print(a>=b)
print(a<=2)
print(type(a==b))
# Out:
# False
# True
# True
# False
# False
# False
# <class 'bool'>

# %% [markdown]
# ###Logical Operators
#
#
#
# 1.  and
# 2.  or
# 3.  not
#
# When used in expressions, the truth value of the expression returned.

# %%
a = 5
b = 6
print(a<b or a==b) # t or f
print(a<b and (a+b)==11) # t and t
print(not a<b) # not t
# Out:
# True
# True
# False

# %% [markdown]
# 1. or : Yields false only when both are false   (Or checks if either condition is true)
# 2. and : Yields true only if both conditions are true (and checks if both conditions are true)
# 3. not: Complements true to false and false to true

# %% [markdown]
# Assignment Operators: used to assign values to a variable

# %% [markdown]
# e.g: =, +=, -=, %=

# %%
x = 2
print(x)
x += 2   # equivalent to x = x + 2
print(x)
# Out:
# 2
# 4

# %% [markdown]
# None Type: The None keyword is used to define a null value, or no value at all.
#
# None is not the same as 0, False, or an empty string. None is a data type of its own (NoneType) and only None can be None.

# %%
a = None
b = a or 4
c = None and 4
print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# None <class 'NoneType'>
# 4 <class 'int'>
# None <class 'NoneType'>

# %% [markdown]
# # Conditional Statements:  used to take decisions in python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Age = 17
 # simple if....else
if Age >= 18:                                            #if(condition):
  print("you can vote")                                        #statement
else:                                                    #elif(condition):
  print("You can't vote")                                        #statement
                                                          #else:
                                                                 #statement
# Out:
# You can't vote

# %%
Summer = False
Winter = True
Rainy = False

if(Summer):
  print("Lets eat ice cream!")
elif(Winter):
  print("Lets play with snow!")
elif(Rainy):
  print("Lets drink Chai!")
else:
  print("Lets just go and study:/")
# Out:
# Lets play with snow!

# %% [markdown]
# Nested condtional statements:

# %%
## if number is positive or negative

i = -15

if i != 0:
    if i > 0:
        print("Positive")
    # condition 3
    elif i < 0:
        print("Negative")
elif i == 0:   #use == as we are comapring i and 0, not assigning i as 0
  print("zero")
else:
  print("invalid, checking only numbers")
# Out:
# Negative

# %% [markdown]
# #LOOPS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For loop:

# %%
for i in range(1,10):      # range function gets a range of integers from 1 to 9 (the last number is not included)
# for i in (1,2,3, 4, 5 ,6, 7, 8, 9)
  print(i)     # prints all numbers from 1 to 9
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# Break statement

# %%
for i in range(1,10):
  print (i)
  if i > 5:
    break           # this break statements breaks off from the loop
    #this prints from 1 to 6, because only after the print statement it checks if i > 5 and breaks away from the loop
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# Nested Loop:

# %% [markdown]
# Loops within loops

# %%
x = 4
for i in range(1, x + 1):
  for j in range(1, i + 1):
    print(j, end = "")
  print()
# Out:
# 1
# 12
# 123
# 1234

# %% [markdown]
# While loop:

# %%
number = int(input('Enter a number: '))

total = 0

# iterate until the user enters 0
while number != 0:
    total += number
    number = int(input('Enter a number: '))

print('The sum is', total)
# Out:
# Enter a number: 12
# Enter a number: 45
# Enter a number: 89
# Enter a number: 0
# The sum is 146

# %%
for i in range(5):     # creates a range of integers from 0 to 4    for i in (0,1,2,3,4)
  print("AI club - Summer School")
# Out:
# AI club - Summer School
# AI club - Summer School
# AI club - Summer School
# AI club - Summer School
# AI club - Summer School

# %% [markdown]
# If we don't use loops, we'd have to use the print statement 5 times !!

# %% [markdown]
# #Functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
### Defining a simple function:

def add_nums(a, b):     # a, b are parameters of the function
  return a+b

add_nums(2,3)            # 2,3 are the arguments passed
print(add_nums(2,3))
# Out:
# 5

# %%
##defining a function to check if a number is odd or even

def odd_even(num):
  if num % 2 == 0:
    return 'Even'
  else:
    return 'Odd'

# %%
print(odd_even(8))
print(odd_even(5))
# Out:
# Even
# Odd

# %%
## if no function us used:
num = 4
if num % 2 == 0:
    print('Even')
else:
    print('Odd')


num = 5
if num % 2 == 0:
    print('Even')
else:
    print('Odd')


### Tedious to check for many numbers

# %% [markdown]
# # Classes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# example class

class Book:          # class is a keyword
  # class variable: shared by all instances of a class
  Type = "Fiction"
  Name = "Harry Potter"
  price = "300"

  # member function/ method
  def reading(self):
    print('read')

### INSTIAITING AN OBJECT
c1 = Book()        # creating an instance of book
c1.reading()        # how to call a method under a class
# Out:
# read

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Vehicle:

    # class variable: shared by all instances of a class
    vehicle_type = 'car'

    # init method or constructor
    def __init__(self, company1, color1):

        # instance variables

        self.company = company1             #here company is the attribute and company1 is the value
        self.color = color1

    # method to display details
    def printing(self):
        print('Vehicle type: ', self.vehicle_type)
        print('company: ', self.company)
        print('color: ', self.color)



C1 = Vehicle("Ferrari", "red")
C2 = Vehicle("Mercedes", "gold")

# displays details of C1
print('C1 details: ', end = '')
C1.printing()

# accessing using class names, attributes can be accessed viw the . operator
print("\naccessing class variable using class name")
print(C1.color)
print(C2.company)
# Out:
# C1 details: Vehicle type:  car
# company:  Ferrari
# color:  red
#
# accessing class variable using class name
# red
# Mercedes

# %%
print(C1.vehicle_type)
# Out:
# car

# %%
C1 = Vehicle()     # raises error because you need the arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-953b0e8cb4aa> in <cell line: 1>()
# ----> 1 C1 = Vehicle()
#
# TypeError: Vehicle.__init__() missing 2 required positional arguments: 'company1' and 'color1'

# %% [markdown]
# INHERITANCE: capability of one class to derive or inherit the properties from another class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class company:
  def __init__(self):
    self.ceo = "mr X"
    self.company_name = "ABC"

  def show(self):
    print(f"Company : {self.company_name}")
    print(f"CEO : {self.ceo}")

class Salesemployee(company):
   def __init__(self,name):
     company.__init__(self)
     self.name = name
     self.salary = "20000"

   def printsalary(self):
     print(f"Salary:{self.salary}")

class Serviceemployee(company):
   def __init__(self,name,branch_name):
     company.__init__(self)
     self.branch_name  = branch_name

   def branch(self):

     print(f"Branch:{self.branch_name}")

emp1 = Salesemployee("mr A")
print(emp1.show())
print(emp1.printsalary())

print("\n")

emp2 = Serviceemployee("mr B","Delhi")
print(emp2.show())
print(emp2.branch())
# Out:
# Company : ABC
# CEO : mr X
# None
# Salary:20000
# None
#
#
# Company : ABC
# CEO : mr X
# None
# Branch:Delhi
# None
